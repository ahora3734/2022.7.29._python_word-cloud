# %% [markdown]
# <a href="https://colab.research.google.com/github/ahora3734/2022.7._python_word-cloud/blob/main/%EC%9B%8C%EB%93%9C%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======= 형태소 분석을 위해 한글 분석 모듈 konlpy를 설치한다. =============
# !python -m pip install konlpy
import konlpy 
print('KoNLPy version...:', konlpy.__version__)
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 448 kB 49.8 MB/s
# ...
# KoNLPy version...: 0.6.0

# %%
# 한국어 텍스트 분석에 필요한 모듈(konlpy)의 Open Korean Text 형태소 분석기를 불러온다.
from konlpy.tag import Okt  

# Open Korean Text 형태소 분석기 객체를 생성한다.
okt = Okt()

# %%
# 파일의 각 문장을 꺼낸 후 형태소 분석기를 통해 명사만 추려내 리스트에 담는다.
file_path = '/content/drive/MyDrive/colab/04_워드클라우드/과학기술기본법.txt'
file = open(file_path).read()
words = [word for word in okt.nouns(file)]
len(words)
print(words)
# Out:
# ['과학기술', '기본', '법', '시행', '법률', '제', '호', '일부', '개정', '과학기술', '정보통신부', '과학기술', '정책', '제', '장', '총칙', '문체', '버튼', '연혁', '제', '목적', '이', '법', '과학기술', '발전', '위', '기반', '조성하', '과학기술', '혁신', '국가경쟁력', '국민', '경제', '발전', '도모', '국민', '삶', '질', '높이', '인류사', '회의', '발전', '이바지', '함', '목적', '전문', '개정', '문체', '버튼', '연혁', '제', '기본', '이념', '이', '법', '과학기술', '혁신', '인간', '존엄', '바탕', '자연환경', '및', '사회', '윤리', '가치', '조화', '경제', '사회', '발전', '원동력', '과학기술', '자율성', '창의성', '존중', '자연과학', '인문', '사회과학', '서로', '균형', '계', '발전', '함', '이념', '전문', '개정', '문체', '버튼', '연혁', '제', '다른', '법률', '관계', '과학기술', '관', '다른', '법률', '제정', '거나', '개정', '때', '이', '법', '목적', '이념', '전문', '개정', '문체', '버튼', '연혁', '제', '국가', '등', '책무', '과학기술', '윤리', '국가', '과학기술', '혁신', '통한', '경제', '사회', '발전', '위', '종합', '시책', '추진', '지방자치단체', '국가', '시책', '지역', '특성', '고려', '지방', '과학기술', '진흥', '시책', '추진', '국가', '지방자치단체', '과학기술', '관', '법령', '조례', '제정', '거나', '개정', '경우', '이', '법', '목적', '부합', '신설', '기업', '교육', '기관', '연구기관', '및', '과학기술', '관련', '기관', '단체', '등', '과
# ...

# %%
from collections import Counter

# words 리스트에 있는 서로 다른 명사의 개수 구한다. 
count = Counter(words)    
len(count)
print(count)
# Out:
# Counter({'과학기술': 276, '제': 188, '및': 136, '연구개발': 131, '개정': 130, '사업': 118, '국가': 107, '정부': 86, '위': 83, '등': 77, '버튼': 74, '문체': 69, '추진': 68, '항': 68, '연혁': 66, '수': 63, '기관': 61, '관련': 60, '장관': 59, '정보통신부': 54, '정': 52, '관': 51, '지원': 51, '계획': 48, '그': 45, '기술': 45, '장': 42, '연구기관': 41, '사항': 41, '시책': 39, '촉진': 39, '대통령령': 39, '투자': 38, '신설': 37, '평가': 35, '전문': 34, '예산': 32, '삭제': 32, '중앙': 30, '행정기관': 30, '육성': 30, '단체': 28, '중': 28, '대한': 27, '출연': 27, '진흥': 26, '인력': 26, '제출': 26, '정책': 24, '혁신': 23, '활용': 23, '다음': 22, '연구': 22, '관리': 22, '관계': 21, '수행': 21, '각': 21, '호의': 21, '교육': 20, '분야': 20, '기획재정부장관': 20, '운영': 20, '법': 19, '발전': 19, '기업': 19, '지방': 18, '지식': 18, '방향': 18, '기금': 18, '거나': 17, '지방자치단체': 17, '과학': 17, '별': 17, '회의': 16, '사회': 16, '시행': 15, '일부': 15, '이': 15, '성과': 15, '효율': 15, '의': 15, '연도': 15, '조정': 15, '조사': 15, '분석': 15, '설립': 15, '경비': 15, '지정': 15, '종합': 14, '창의': 14, '마련': 14, '이하': 14, '협력': 14, '문화': 14, '매년': 14, '전부': 14, '전략': 13, '정보': 
# ...

# %%
# 가장 자주 출현하는 명사 100개를 추출한다.
data = count.most_common(100)
data[:5]
# Out:
# [('과학기술', 276), ('제', 188), ('및', 136), ('연구개발', 131), ('개정', 130)]

# %%
# --- 한글 워드 클라우드를 그리기 위해 한글 폰트를 설치한다.
# 한글 폰트를 설치한다.
# !apt -qq -y install fonts-nanum
 
# 나눔바른고딕(NanumBarunGothic)을 사용하기 위해 경로를 포함시킨다.
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
# Out:
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155225 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
  font_path=fontpath, # 나눔바른고딕
  relative_scaling=0.2,
  background_color='white',
).generate_from_frequencies(dict(data))

from matplotlib import pyplot

pyplot.figure(figsize=(16, 10))  # width, height in inches
pyplot.imshow(wordcloud)
pyplot.axis('off')
pyplot.show()

# %%
import numpy as np # 이미지 데이터를 다루기 위해
from PIL import Image # 이미지를 위한 라이브러리

#img_mask = np.array(Image.open('/content/drive/MyDrive/colab/04_워드클라우드/black_mask.png'))

img_mask = Image.open('/content/drive/MyDrive/colab/04_워드클라우드/black_mask.png')
img_mask = Image.new("RGB", img_mask.size, (255,255,255))
img_mask.paste(icon,icon)
img_mask = np.array(img_mask)

# %%
img_mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
  font_path=fontpath, # 나눔바른고딕
  background_color='white',
  relative_scaling=0.2,
  mask=img_mask  
  ).generate_from_frequencies(dict(data))

from matplotlib import pyplot

pyplot.figure(figsize=(10, 10))  # width, height in inches
pyplot.imshow(wordcloud)
pyplot.axis('off')
pyplot.show()
